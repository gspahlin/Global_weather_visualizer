# %%
# This is the script designed to call open weather api to return .csv data for analysis
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from pprint import pprint

# Import API key
from open_w import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %%
#In this cell my goal is to build an api call to openweather api 
#This is my test case for London
#need Max Temp, humidity%, cloudiness%, windspeed, country code, date, name, latitude and longitude 

#assembling call url and making test call

base_url = "http://api.openweathermap.org/data/2.5/weather?q="

test_city = "London"

url = f'{base_url}{test_city}&appid={api_key}'

response = requests.get(url)

weather = response.json()

#Notes from json entry: entry is a dict
#key 'coord' returns a dict 'lat'  is key for latitude, 'lon' is key for longitude
#key 'name' returns name
#key 'wind' returns a dict 'speed' returns wind speed value
#key 'clouds' returns a dict 'all' returns the value
#key 'main' returns a dictionary with most of the data of interest: 'temp' calls temp (in K),
#     'humidity' returns humidity, 'temp_max' returns max temp
#key 'dt' returns the date
#key 'sys' returns a dict, 'country' returns a country code


#calling some dict keys from the json object returned by the call
wspeed = float(weather['wind']['speed'])

temp_c = float(weather['main']['temp']) - 273.15

humid = float(weather['main']['humidity'])

c_cover = float(weather['clouds']['all'])


#test output
print('London Weather')
print(f'Temperature is {temp_c} degrees celsius')
print(f'Wind speed is {wspeed} m/s')
print(f'Relative humidity is {humid} percent')
print(f'Cloud cover is {c_cover} percent')
# Out:
# London Weather
# Temperature is 3.6100000000000136 degrees celsius
# Wind speed is 3.1 m/s
# Relative humidity is 86.0 percent
# Cloud cover is 75.0 percent

# %%
#In this cell I need to bulid a loop to automate calls to the api calls, and store the data in a dataframe
#I also need to export that to a .csv

#tc_list = ['Belfast', 'Detroit', 'Potatodict', 'Tokyo'] this list was used for testing

#set up lists for data

#dates
dates = []

#city names
c_names = []

#country code
c_codes = []

#latitude coordinate
lats = []

#longitude coordinate
lons = []

#max temperature
m_temp = []

#cloudiness
c_covs = []

#humidity
hums = []


#start of the for loop
for city in cities:

    #construct a url using the current city from list cities
    iurl = f'{base_url}{city}&appid={api_key}'
    
    #call the api and request a response
    output = requests.get(iurl)
    
    #not sure why I'm doing this - need to check on this line (seems to transform output object in some way)
    w_data = output.json()
    
    #try to append data to the lists
    
    try:
        #append commands to store data in lists
        dates.append(w_data['dt'])
        c_names.append(w_data['name'])
        c_codes.append(w_data['sys']['country'])
        lats.append(float(w_data['coord']['lat']))
        lons.append(float(w_data['coord']['lon']))
        m_temp.append(float(w_data['main']['temp_max'] - 273.15))
        c_covs.append(float(w_data['clouds']['all']))
        hums.append(float(w_data['main']['humidity']))
        
        #output statement to confirm success
        print(f'Data from {city} stored in memory')
        
    except:
        
        #output statement for failure case
        print(f'Call failed for {city}')
        
    #line to tell the loop to allow a little time before the next call
    #this comes from the time module and tells it to sleep for however long it took to get a response
    time.sleep(output.elapsed.total_seconds())
# Out:
# Data from sorong stored in memory
# Data from kapaa stored in memory
# Data from hay river stored in memory
# Data from punta arenas stored in memory
# Data from hilo stored in memory
# Data from rikitea stored in memory
# Data from qaanaaq stored in memory
# Data from simoes stored in memory
# Data from viedma stored in memory
# Data from bluff stored in memory
# Data from vilyuysk stored in memory
# Data from vaini stored in memory
# Call failed for taolanaro
# Data from walvis bay stored in memory
# Data from tiassale stored in memory
# Data from severo-kurilsk stored in memory
# Data from san patricio stored in memory
# Data from lebu stored in memory
# Data from komsomolskiy stored in memory
# Data from cape town stored in memory
# Data from hermanus stored in memory
# Data from butaritari stored in memory
# Data from ust-nera stored in memory
# Data from avarua stored in memory
# Data from luau stored in memory
# Data from airai stored in memory
# Data from east london stored in memory
# Data from wuhu stored in memory
# Data from derzhavinsk stored in memory
# Data from nikolskoye stored in memory
# Call failed for belushya guba
# Data from albany stored in memory
# Data from rabo de peixe stored in memory
# Data from husavik stored in memory
# Data from yerofey pavlovich stored in memory
# Data from timmins stored in memory
# Data from mount gambier stored in memory
# Data from gigmoto stored in memory
# Data from guerrero negro stored in memory
# Data from shahe stored in memory
# Data from hobart stored in memory
# Data from arraial do cabo stored in memory
# Data from bambous virieux stored in memory
# Data from tasiilaq stored in memory
# Data from dikson stored in memory
# Data from vitim stored in memory
# Data from nanortalik stored in memory
# Data from russell stored in memory
# Data from sibolga stored in memory
# Data from ushuaia stored in memory
# Data from honolulu stored in memory
# Data from gaoua stored in memory
# Data from cidreira stored in memory
# Call failed for longlac
# Data from sinnamary stored in memory
# Data from carnarvon stored in memory
# Call failed for tumannyy
# Data from broome stored in memory
# Data from brewster stored in memory
# Data from busselton stored in memory
# Data from neiafu stored in memory
# Data from chokurdakh stored in memory
# Data from bhag stored in memory
# Data from new norfolk stored in memory
# Data from alot stored in memory
# Call failed for umm durman
# Data from atuona stored in memory
# Data from te anau stored in memory
# Call failed for phan rang
# Data from esperance stored in memory
# Data from antofagasta stored in memory
# Data from vila stored in memory
# Data from puerto ayora stored in memory
# Data from chicama stored in memory
# Data from mataura stored in memory
# Data from lorengau stored in memory
# Data from shimoda stored in memory
# Data from mar del plata stored in memory
# Data from hasaki stored in memory
# Data from sobolevo stored in memory
# Call failed for palabuhanratu
# Data from saint-joseph stored in memory
# Data from karak stored in memory
# Data from evensk stored in memory
# Call failed for amderma
# Data from gushikawa stored in memory
# Data from narsaq stored in memory
# Data from boali stored in memory
# Data from bull savanna stored in memory
# Data from bredasdorp stored in memory
# Data from mataram stored in memory
# Data from hofn stored in memory
# Data from ken caryl stored in memory
# Call failed for saleaula
# Data from liverpool stored in memory
# Data from hithadhoo stored in memory
# Data from tuktoyaktuk stored in memory
# Data from castro stored in memory
# Data from necochea stored in memory
# Data from clonakilty stored in memory
# Data from indian head stored in memory
# Call failed for sinjah
# Data from srednekolymsk stored in memory
# Data from batemans bay stored in memory
# Data from markova stored in memory
# Data from tocopilla stored in memory
# Data from rocha stored in memory
# Data from touros stored in memory
# Data from norman wells stored in memory
# Data from guadalupe y calvo stored in memory
# Call failed for illoqqortoormiut
# Call failed for tsihombe
# Data from borisoglebskiy stored in memory
# Data from isangel stored in memory
# Data from port macquarie stored in memory
# Data from grindavik stored in memory
# Data from beringovskiy stored in memory
# Data from hamilton stored in memory
# Data from henties bay stored in memory
# Data from lata stored in memory
# Data from tiksi stored in memory
# Data from cherskiy stored in memory
# Call failed for attawapiskat
# Data from dunedin stored in memory
# Data from saint-pierre stored in memory
# Data from cap malheureux stored in memory
# Data from bethel stored in memory
# Data from irituia stored in memory
# Data from kahului stored in memory
# Data from tilichiki stored in memory
# Data from ayan stored in memory
# Data from nalut stored in memory
# Call failed for parras
# Data from yeniseysk stored in memory
# Data from matagami stored in memory
# Data from nautla stored in memory
# Data from sitka stored in memory
# Data from haines junction stored in memory
# Data from lakshmeshwar stored in memory
# Data from upernavik stored in memory
# Data from okhotsk stored in memory
# Data from aklavik stored in memory
# Call failed for tasbuget
# Data from livramento stored in memory
# Data from kilindoni stored in memory
# Data from portland stored in memory
# Data from havoysund stored in memory
# Data from saint anthony stored in memory
# Data from imbituba stored in memory
# Data from naryan-mar stored in memory
# Data from porto walter stored in memory
# Data from saint-philippe stored in memory
# Data from olafsvik stored in memory
# Data from winnemucca stored in memory
# Data from katherine stored in memory
# Data from provideniya stored in memory
# Data from souillac stored in memory
# Data from port alfred stored in memory
# Data from mahebourg stored in memory
# Data from puerto palomas stored in memory
# Data from georgetown stored in memory
# Data from hirara stored in memory
# Data from turayf stored in memory
# Data from grafton stored in memory
# Data from inhambane stored in memory
# Data from faranah stored in memory
# Data from kyzyl-suu stored in memory
# Data from port-gentil stored in memory
# Data from tarko-sale stored in memory
# Data from ostrovnoy stored in memory
# Data from songjianghe stored in memory
# Data from coihaique stored in memory
# Data from novaya bryan stored in memory
# Call failed for yanan
# Data from rio gallegos stored in memory
# Data from acapulco stored in memory
# Data from eregli stored in memory
# Data from port augusta stored in memory
# Call failed for barbar
# Data from qui nhon stored in memory
# Data from alta floresta stored in memory
# Data from pijijiapan stored in memory
# Data from nueve de julio stored in memory
# Data from vila velha stored in memory
# Data from milos stored in memory
# Data from da lat stored in memory
# Data from sorland stored in memory
# Data from lagoa stored in memory
# Data from goma stored in memory
# Data from constitucion stored in memory
# Data from jesus maria stored in memory
# Data from oussouye stored in memory
# Data from lasa stored in memory
# Data from biak stored in memory
# Data from kavaratti stored in memory
# Data from fandriana stored in memory
# Call failed for ciras
# Data from halifax stored in memory
# Data from alofi stored in memory
# Data from anchorage stored in memory
# Data from cacequi stored in memory
# Data from harper stored in memory
# Data from roald stored in memory
# Data from barbosa ferraz stored in memory
# Data from yellowknife stored in memory
# Data from guadalajara stored in memory
# Data from ponta delgada stored in memory
# Data from faanui stored in memory
# Data from sumenep stored in memory
# Data from mykolayivka stored in memory
# Data from port elizabeth stored in memory
# Data from pinerolo stored in memory
# Data from zhanaozen stored in memory
# Data from mandera stored in memory
# Data from vardo stored in memory
# Data from codrington stored in memory
# Data from notre-dame-du-lac stored in memory
# Data from sao filipe stored in memory
# Data from jamestown stored in memory
# Data from victoria stored in memory
# Data from margineni stored in memory
# Data from salalah stored in memory
# Data from nizwa stored in memory
# Data from kutum stored in memory
# Data from tura stored in memory
# Data from ahipara stored in memory
# Data from coari stored in memory
# Data from karratha stored in memory
# Data from tuatapere stored in memory
# Data from saint-denis stored in memory
# Data from hami stored in memory
# Data from noumea stored in memory
# Data from venezuela stored in memory
# Data from hambantota stored in memory
# Data from santa cruz stored in memory
# Data from louis trichardt stored in memory
# Call failed for vaitupu
# Data from bengkulu stored in memory
# Data from noyabrsk stored in memory
# Call failed for rolim de moura
# Data from palm coast stored in memory
# Data from quatre cocos stored in memory
# Data from ipixuna stored in memory
# Data from leo stored in memory
# Data from fare stored in memory
# Data from cocula stored in memory
# Data from ternate stored in memory
# Data from praia da vitoria stored in memory
# Call failed for dekoa
# Data from chupa stored in memory
# Data from mbandaka stored in memory
# Data from kodiak stored in memory
# Data from nobres stored in memory
# Data from saskylakh stored in memory
# Data from tupik stored in memory
# Call failed for barentsburg
# Data from pevek stored in memory
# Data from clyde river stored in memory
# Data from negombo stored in memory
# Data from aripuana stored in memory
# Data from port lincoln stored in memory
# Data from newcastle stored in memory
# Data from kalemie stored in memory
# Data from berlevag stored in memory
# Data from olavarria stored in memory
# Data from ursulo galvan stored in memory
# Data from troitsko-pechorsk stored in memory
# Data from elat stored in memory
# Data from saldanha stored in memory
# Data from khatanga stored in memory
# Data from kavieng stored in memory
# Call failed for kamenskoye
# Data from palana stored in memory
# Call failed for nizhneyansk
# Data from sur stored in memory
# Data from atar stored in memory
# Call failed for toliary
# Data from gogrial stored in memory
# Data from payyannur stored in memory
# Data from nome stored in memory
# Data from marystown stored in memory
# Data from kankon stored in memory
# Data from torbay stored in memory
# Data from iqaluit stored in memory
# Data from saint-jean-port-joli stored in memory
# Data from lermontovka stored in memory
# Data from niteroi stored in memory
# Data from cairns stored in memory
# Data from ribeira grande stored in memory
# Data from matara stored in memory
# Data from tual stored in memory
# Data from lisakovsk stored in memory
# Data from ushtobe stored in memory
# Data from mogadishu stored in memory
# Call failed for utiroa
# Data from nemuro stored in memory
# Data from alice springs stored in memory
# Data from tateyama stored in memory
# Data from candido mendes stored in memory
# Data from avera stored in memory
# Data from zemetchino stored in memory
# Data from patacamaya stored in memory
# Data from canhaway stored in memory
# Data from zachary stored in memory
# Call failed for ardistan
# Data from atbasar stored in memory
# Data from barrow stored in memory
# Data from adrar stored in memory
# Data from caravelas stored in memory
# Data from lewistown stored in memory
# Call failed for jinchengjiang
# Data from afsin stored in memory
# Data from rio de jesus stored in memory
# Call failed for mahadday weyne
# Data from gorontalo stored in memory
# Data from ust-maya stored in memory
# Data from yefremov stored in memory
# Data from muros stored in memory
# Data from chuy stored in memory
# Data from alamos stored in memory
# Data from vila do maio stored in memory
# Data from changzhou stored in memory
# Data from padang stored in memory
# Data from kushiro stored in memory
# Data from porto novo stored in memory
# Data from byron bay stored in memory
# Data from totness stored in memory
# Data from freeport stored in memory
# Data from port keats stored in memory
# Data from qeshm stored in memory
# Data from eenhana stored in memory
# Data from sendafa stored in memory
# Data from fortuna stored in memory
# Data from thompson stored in memory
# Data from bilibino stored in memory
# Data from cabedelo stored in memory
# Data from fianarantsoa stored in memory
# Data from belaya gora stored in memory
# Data from anadyr stored in memory
# Data from merauke stored in memory
# Data from san pedro de uraba stored in memory
# Data from antalaha stored in memory
# Data from sibu stored in memory
# Data from bafilo stored in memory
# Call failed for kuche
# Call failed for kadykchan
# Data from boa vista stored in memory
# Data from la ronge stored in memory
# Data from longyearbyen stored in memory
# Data from pemangkat stored in memory
# Data from krasnoselkup stored in memory
# Data from geraldton stored in memory
# Data from utrera stored in memory
# Data from moussoro stored in memory
# Data from ilulissat stored in memory
# Data from semporna stored in memory
# Data from kruisfontein stored in memory
# Call failed for chagda
# Data from korla stored in memory
# Call failed for warqla
# Call failed for grand river south east
# Data from bonavista stored in memory
# Data from carutapera stored in memory
# Data from natal stored in memory
# Data from lingsugur stored in memory
# Data from camacha stored in memory
# Data from brae stored in memory
# Data from revelstoke stored in memory
# Data from artvin stored in memory
# Data from kosa stored in memory
# Data from roma stored in memory
# Data from ranau stored in memory
# Data from elumalai stored in memory
# Data from mount isa stored in memory
# Data from gemena stored in memory
# Data from preston stored in memory
# Data from mugur-aksy stored in memory
# Data from inongo stored in memory
# Data from vila franca do campo stored in memory
# Data from frolovo stored in memory
# Data from chapais stored in memory
# Data from vostok stored in memory
# Data from lavrentiya stored in memory
# Data from kerouane stored in memory
# Call failed for sentyabrskiy
# Data from petropavlovsk-kamchatskiy stored in memory
# Data from hokitika stored in memory
# Data from anloga stored in memory
# Data from port-cartier stored in memory
# Data from oranjemund stored in memory
# Data from acari stored in memory
# Data from nakamura stored in memory
# Data from abu zabad stored in memory
# Data from kumluca stored in memory
# Data from leningradskiy stored in memory
# Data from iberia stored in memory
# Data from benguela stored in memory
# Data from norrtalje stored in memory
# Data from stonehaven stored in memory
# Data from riverton stored in memory
# Data from klaksvik stored in memory
# Data from lodeynoye pole stored in memory
# Call failed for vitimskiy
# Data from khash stored in memory
# Data from bissau stored in memory
# Data from la orilla stored in memory
# Data from dumbea stored in memory
# Data from saint george stored in memory
# Call failed for gulshat
# Data from nishihara stored in memory
# Data from burns lake stored in memory
# Call failed for umzimvubu
# Data from san luis stored in memory
# Data from cayenne stored in memory
# Data from igarka stored in memory
# Data from paita stored in memory
# Data from urucara stored in memory
# Data from port hedland stored in memory
# Data from puerto rico stored in memory
# Data from cabo san lucas stored in memory
# Data from corcova stored in memory
# Data from laguna stored in memory
# Data from mildura stored in memory
# Data from duldurga stored in memory
# Data from saint-augustin stored in memory
# Data from sisimiut stored in memory
# Data from pampa stored in memory
# Call failed for mys shmidta
# Data from miguel hidalgo stored in memory
# Data from ust-tsilma stored in memory
# Data from praya stored in memory
# Data from santa clara stored in memory
# Data from clyde stored in memory
# Data from ancud stored in memory
# Call failed for krasnoyarsk-66
# Data from elko stored in memory
# Data from phan thiet stored in memory
# Data from salinas stored in memory
# Data from beloha stored in memory
# Data from griffith stored in memory
# Data from pilar stored in memory
# Data from asfi stored in memory
# Data from baykit stored in memory
# Data from basco stored in memory
# Data from nangavalli stored in memory
# Data from hervey bay stored in memory
# Data from kuandian stored in memory
# Data from verkhoyansk stored in memory
# Data from mopipi stored in memory
# Data from nioro stored in memory
# Data from gannan stored in memory
# Data from katobu stored in memory
# Data from ratangarh stored in memory
# Data from nosy varika stored in memory
# Data from nirmal stored in memory
# Data from biskamzha stored in memory
# Data from changji stored in memory
# Call failed for kazalinsk
# Data from kaitangata stored in memory
# Data from marabba stored in memory
# Data from ashford stored in memory
# Data from sale stored in memory
# Data from tucurui stored in memory
# Data from waverly stored in memory
# Data from moron stored in memory
# Data from san pedro de ycuamandiyu stored in memory
# Data from aloleng stored in memory
# Data from lethem stored in memory
# Data from lompoc stored in memory
# Data from makakilo city stored in memory
# Data from kokopo stored in memory
# Data from carmen stored in memory
# Data from taos stored in memory
# Data from celina stored in memory
# Data from mirabad stored in memory
# Data from bambanglipuro stored in memory
# Data from ust-kuyga stored in memory
# Call failed for lawan kuda baharu
# Data from barranco stored in memory
# Data from umm lajj stored in memory
# Data from nixa stored in memory
# Data from erzin stored in memory
# Data from lagunas stored in memory
# Data from pyay stored in memory
# Call failed for ruatoria
# Data from washington stored in memory
# Call failed for ijaki
# Data from kingman stored in memory
# Data from sioux lookout stored in memory
# Data from caruray stored in memory
# Data from upata stored in memory
# Data from elban stored in memory
# Data from arman stored in memory
# Data from chachapoyas stored in memory
# Data from erdenet stored in memory
# Data from fairbanks stored in memory
# Data from axim stored in memory
# Data from port blair stored in memory
# Data from itacare stored in memory
# Data from fort nelson stored in memory
# Data from mathbaria stored in memory
# Data from kailua stored in memory
# Data from safaga stored in memory
# Data from kaberamaido stored in memory
# Data from olinda stored in memory
# Data from abu kamal stored in memory
# Data from umreth stored in memory
# Data from dondo stored in memory
# Data from cine stored in memory
# Data from paris stored in memory
# Data from dalvik stored in memory
# Data from oistins stored in memory
# Data from colombo stored in memory
# Data from meulaboh stored in memory
# Data from ananas stored in memory
# Data from calvinia stored in memory
# Call failed for samusu
# Data from zabol stored in memory
# Data from belmonte stored in memory
# Data from igrim stored in memory
# Data from tumen stored in memory
# Data from najran stored in memory
# Data from yichang stored in memory
# Data from karimganj stored in memory
# Data from kaka stored in memory
# Call failed for marcona
# Data from parabel stored in memory
# Data from mareeba stored in memory
# Data from dali stored in memory
# Data from taseyevo stored in memory
# Data from siavonga stored in memory
# Data from zell am see stored in memory
# Call failed for jomalig
# Data from yumen stored in memory
# Data from baghdad stored in memory
# Data from tharad stored in memory
# Data from miri stored in memory
# Data from talnakh stored in memory
# Data from taoudenni stored in memory
# Data from sijunjung stored in memory
# Data from voh stored in memory
# Data from miandrivazo stored in memory
# Data from polunochnoye stored in memory
# Data from ambatofinandrahana stored in memory
# Data from senanga stored in memory
# Data from naze stored in memory
# Call failed for stoyba
# Data from nadvoitsy stored in memory
# Data from gornoye loo stored in memory
# Data from pahrump stored in memory
# Data from gorom-gorom stored in memory
# Data from praia stored in memory
# Data from bubaque stored in memory
# Data from sabang stored in memory
# Data from staryy nadym stored in memory
# Data from itaituba stored in memory
# Data from zagora stored in memory
# Data from verkhnyaya inta stored in memory
# Data from hearst stored in memory
# Data from awbari stored in memory
# Data from morgan city stored in memory
# Data from aborlan stored in memory
# Data from takoradi stored in memory
# Data from hope mills stored in memory
# Data from tecoanapa stored in memory
# Data from trairi stored in memory
# Data from coromandel stored in memory
# Data from ihosy stored in memory
# Data from mayo stored in memory
# Data from aykhal stored in memory
# Call failed for khagrachari
# Data from tarauaca stored in memory
# Data from bilma stored in memory
# Data from kenai stored in memory
# Data from bayan stored in memory
# Data from segezha stored in memory
# Data from namibe stored in memory
# Data from khoy stored in memory
# Call failed for nguiu
# Data from cortez stored in memory
# Data from dingle stored in memory
# Data from syamzha stored in memory
# Data from yelnya stored in memory
# Data from asau stored in memory
# Call failed for bolungarvik
# Call failed for mendahara
# Data from yar-sale stored in memory
# Data from coquimbo stored in memory
# Data from emerald stored in memory
# Data from cloppenburg stored in memory
# Data from yinchuan stored in memory
# Data from agua verde stored in memory
# Data from virginia beach stored in memory
# Data from rio grande stored in memory
# Call failed for grand centre
# Data from palmer stored in memory
# Data from lyubar stored in memory
# Data from deputatskiy stored in memory

# %%
#compose a dataframe from the lists accumulated

w_dict = {'city_name': c_names, 'country':c_codes, 'date': dates, 'lat':lats, 'lon':lons, 'max_temp_C': m_temp,
         'cloud_cover%': c_covs, 'humidity%': hums}

w_df = pd.DataFrame(w_dict)

w_df.head(15)
# Out:
#           city_name country        date      lat       lon  max_temp_C  \
# 0            Sorong      ID  1609877909  -0.8833  131.2500       26.17
# 1             Kapaa      US  1609877909  22.0752 -159.3190       24.00
# 2         Hay River      CA  1609877910  60.8156 -115.7999      -18.00
# 3      Punta Arenas      CL  1609877910 -53.1500  -70.9167       14.00
# 4              Hilo      US  1609877809  19.7297 -155.0900       24.00
# 5           Rikitea      PF  1609877911 -23.1203 -134.9692       24.87
# 6           Qaanaaq      GL  1609877911  77.4840  -69.3632      -14.42
# 7            Simões      BR  1609877911  -7.5989  -40.8178       33.91
# 8            Viedma      AR  1609877912 -40.8135  -62.9967       25.00
# 9             Bluff      NZ  1609877912 -46.6000  168.3333       10.00
# 10         Vilyuysk      RU  1609877912  63.7553  121.6247      -33.71
# 11            Vaini      TO  1609877913 -21.2000 -175.2000       26.00
# 12       Walvis Bay      NA  1609877913 -22.9575   14.5053       21.00
# 13         Tiassalé      CI  1609877914   5.8983   -4.8283       25.03
# 14  Severo-Kuril'sk      RU  1609877914  50.6789  156.1250       -9.14
#
#     cloud_cover%  humidity%
# 0          100.0       84.0
# 1           90.0       73.0
# 2           75.0       77.0
# 3           75.0       50.0
# 4            1.0       60.0
# 5            0.0       77.0
# 6          100.0       81.0
# 7           26.0       25.0
# 8           39.0       48.0
# 9           40.0       94.0
# 10         100.0       85.0
# 11          40.0       94.0
# 12         100.0       83.0
# 13          75.0       91.0
# 14          75.0       84.0

# %%
#write an output .csv for the data

w_df.to_csv('city_weather_1_5_21.csv', index = False)
