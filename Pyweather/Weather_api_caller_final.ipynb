# %%
# This is the script designed to call open weather api to return .csv data for analysis
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
from pprint import pprint

# Import API key
from open_w import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %%
#In this cell my goal is to build an api call to openweather api 
#This is my test case for London
#need Max Temp, humidity%, cloudiness%, windspeed, country code, date, name, latitude and longitude 

#assembling call url and making test call

base_url = "http://api.openweathermap.org/data/2.5/weather?q="

test_city = "London"

url = f'{base_url}{test_city}&appid={api_key}'

response = requests.get(url)

weather = response.json()

#Notes from json entry: entry is a dict
#key 'coord' returns a dict 'lat'  is key for latitude, 'lon' is key for longitude
#key 'name' returns name
#key 'wind' returns a dict 'speed' returns wind speed value
#key 'clouds' returns a dict 'all' returns the value
#key 'main' returns a dictionary with most of the data of interest: 'temp' calls temp (in K),
#     'humidity' returns humidity, 'temp_max' returns max temp
#key 'dt' returns the date
#key 'sys' returns a dict, 'country' returns a country code


#calling some dict keys from the json object returned by the call
wspeed = float(weather['wind']['speed'])

temp_c = float(weather['main']['temp']) - 273.15

humid = float(weather['main']['humidity'])

c_cover = float(weather['clouds']['all'])


#test output
print('London Weather')
print(f'Temperature is {temp_c} degrees celsius')
print(f'Wind speed is {wspeed} m/s')
print(f'Relative humidity is {humid} percent')
print(f'Cloud cover is {c_cover} percent')
# Out:
# London Weather
# Temperature is 3.7100000000000364 degrees celsius
# Wind speed is 5.12 m/s
# Relative humidity is 74.0 percent
# Cloud cover is 97.0 percent

# %%
#In this cell I need to bulid a loop to automate calls to the api calls, and store the data in a dataframe
#I also need to export that to a .csv

#tc_list = ['Belfast', 'Detroit', 'Potatodict', 'Tokyo'] this list was used for testing

#set up lists for data

#dates
dates = []

#city names
c_names = []

#country code
c_codes = []

#latitude coordinate
lats = []

#longitude coordinate
lons = []

#max temperature
m_temp = []

#cloudiness
c_covs = []

#humidity
hums = []

#wind speed
wnd = []


#start of the for loop
for city in cities:

    #construct a url using the current city from list cities
    iurl = f'{base_url}{city}&appid={api_key}'
    
    #call the api and request a response
    output = requests.get(iurl)
    
    #not sure why I'm doing this - need to check on this line (seems to transform output object in some way)
    w_data = output.json()
    
    #try to append data to the lists
    
    try:
        #append commands to store data in lists
        dates.append(w_data['dt'])
        c_names.append(w_data['name'])
        c_codes.append(w_data['sys']['country'])
        lats.append(float(w_data['coord']['lat']))
        lons.append(float(w_data['coord']['lon']))
        m_temp.append(float(w_data['main']['temp_max'] - 273.15))
        c_covs.append(float(w_data['clouds']['all']))
        hums.append(float(w_data['main']['humidity']))
        wnd.append(float(w_data['wind']['speed']))
        
        #output statement to confirm success
        print(f'Data from {city} stored in memory')
        
    except:
        
        #output statement for failure case
        print(f'Call failed for {city}')
        
    #line to tell the loop to allow a little time before the next call
    #this comes from the time module and tells it to sleep for however long it took to get a response
    time.sleep(output.elapsed.total_seconds())
# Out:
# Data from georgetown stored in memory
# Data from port elizabeth stored in memory
# Call failed for belushya guba
# Data from port-gentil stored in memory
# Data from rabaul stored in memory
# Data from dingle stored in memory
# Data from arraial do cabo stored in memory
# Data from faanui stored in memory
# Data from lobito stored in memory
# Data from albany stored in memory
# Data from hermanus stored in memory
# Data from busselton stored in memory
# Call failed for warqla
# Data from zverinogolovskoye stored in memory
# Data from samarai stored in memory
# Data from rikitea stored in memory
# Data from ushuaia stored in memory
# Data from fairbanks stored in memory
# Data from namatanai stored in memory
# Data from puerto ayora stored in memory
# Data from catuday stored in memory
# Data from saint george stored in memory
# Data from alofi stored in memory
# Call failed for taolanaro
# Data from qaanaaq stored in memory
# Data from saint-georges stored in memory
# Data from bluff stored in memory
# Data from te anau stored in memory
# Data from jamestown stored in memory
# Data from hilo stored in memory
# Data from dikson stored in memory
# Data from tuatapere stored in memory
# Call failed for sorvag
# Data from cape town stored in memory
# Data from tynda stored in memory
# Data from castro stored in memory
# Data from pontivy stored in memory
# Data from havelock stored in memory
# Data from fortuna stored in memory
# Data from vaini stored in memory
# Data from chokurdakh stored in memory
# Data from mahebourg stored in memory
# Data from bambous virieux stored in memory
# Data from tasiilaq stored in memory
# Data from trairi stored in memory
# Data from chuy stored in memory
# Data from apold stored in memory
# Data from itarema stored in memory
# Data from barrow stored in memory
# Data from takoradi stored in memory
# Data from haines junction stored in memory
# Data from la ronge stored in memory
# Data from ponta delgada stored in memory
# Data from sete stored in memory
# Data from cherskiy stored in memory
# Call failed for illoqqortoormiut
# Data from gopalpur stored in memory
# Data from punta arenas stored in memory
# Data from otavi stored in memory
# Data from joshimath stored in memory
# Data from new norfolk stored in memory
# Data from kaohsiung stored in memory
# Call failed for barentsburg
# Data from harper stored in memory
# Data from mataura stored in memory
# Data from thompson stored in memory
# Call failed for ondorhaan
# Data from innisfail stored in memory
# Data from iqaluit stored in memory
# Data from faya stored in memory
# Data from norman wells stored in memory
# Data from upernavik stored in memory
# Data from narsaq stored in memory
# Data from pevek stored in memory
# Data from machilipatnam stored in memory
# Data from milkovo stored in memory
# Data from kapaa stored in memory
# Data from havre-saint-pierre stored in memory
# Data from bada stored in memory
# Data from torbay stored in memory
# Data from saint-philippe stored in memory
# Data from orbetello stored in memory
# Data from itoman stored in memory
# Data from codrington stored in memory
# Call failed for bacuit
# Data from sao joao da barra stored in memory
# Call failed for mentok
# Data from cairns stored in memory
# Call failed for palabuhanratu
# Data from kanniyakumari stored in memory
# Data from willmar stored in memory
# Data from ulladulla stored in memory
# Data from bethel stored in memory
# Data from goundam stored in memory
# Data from ponta do sol stored in memory
# Data from port alfred stored in memory
# Data from carnarvon stored in memory
# Data from shahreza stored in memory
# Data from celestun stored in memory
# Data from kajaani stored in memory
# Data from karapyshi stored in memory
# Data from venice stored in memory
# Data from bengkulu stored in memory
# Data from hobart stored in memory
# Data from zyryanskoye stored in memory
# Data from forio stored in memory
# Data from ahipara stored in memory
# Data from ancud stored in memory
# Data from cape canaveral stored in memory
# Data from havoysund stored in memory
# Data from yagodnoye stored in memory
# Data from penzance stored in memory
# Data from mar del plata stored in memory
# Data from lianzhou stored in memory
# Data from clyde river stored in memory
# Data from la libertad stored in memory
# Data from paramonga stored in memory
# Call failed for rungata
# Data from safety harbor stored in memory
# Data from biak stored in memory
# Data from khartoum stored in memory
# Data from esperance stored in memory
# Data from homer stored in memory
# Data from bima stored in memory
# Data from chandbali stored in memory
# Data from kodiak stored in memory
# Data from butaritari stored in memory
# Data from avarua stored in memory
# Data from custoias stored in memory
# Data from saskylakh stored in memory
# Data from shubarshi stored in memory
# Data from soc trang stored in memory
# Data from flinders stored in memory
# Data from margate stored in memory
# Data from bud stored in memory
# Data from port keats stored in memory
# Call failed for attawapiskat
# Data from cabo san lucas stored in memory
# Call failed for khormuj
# Data from aswan stored in memory
# Data from ilulissat stored in memory
# Data from bathsheba stored in memory
# Data from gat stored in memory
# Data from sobolevo stored in memory
# Data from perbaungan stored in memory
# Data from ottawa stored in memory
# Call failed for satitoa
# Data from washington stored in memory
# Data from toguchin stored in memory
# Data from caravelas stored in memory
# Data from yellowknife stored in memory
# Call failed for tumannyy
# Data from nikolskoye stored in memory
# Data from avera stored in memory
# Data from isangel stored in memory
# Data from maragogi stored in memory
# Data from brae stored in memory
# Data from east london stored in memory
# Data from tura stored in memory
# Call failed for amderma
# Data from znamenskoye stored in memory
# Data from lebu stored in memory
# Data from sisimiut stored in memory
# Data from christchurch stored in memory
# Data from bilma stored in memory
# Data from doha stored in memory
# Data from toppenish stored in memory
# Data from turukhansk stored in memory
# Data from saint-augustin stored in memory
# Data from moyo stored in memory
# Data from ribeira grande stored in memory
# Data from cap malheureux stored in memory
# Data from airai stored in memory
# Data from sawang daen din stored in memory
# Data from belison stored in memory
# Data from sungaipenuh stored in memory
# Data from saldanha stored in memory
# Data from port hedland stored in memory
# Data from navoi stored in memory
# Data from shorapani stored in memory
# Data from mandla stored in memory
# Data from cayenne stored in memory
# Call failed for mys shmidta
# Data from aripuana stored in memory
# Data from temba stored in memory
# Data from vesyegonsk stored in memory
# Data from chilca stored in memory
# Data from nsanje stored in memory
# Data from rocky mountain house stored in memory
# Data from hambantota stored in memory
# Data from pacific grove stored in memory
# Data from husavik stored in memory
# Data from kelo stored in memory
# Call failed for tsihombe
# Data from paraiso stored in memory
# Data from bay roberts stored in memory
# Data from aguilas stored in memory
# Data from victoria stored in memory
# Data from marsa matruh stored in memory
# Data from yarada stored in memory
# Data from port lincoln stored in memory
# Call failed for abu jubayhah
# Data from malanje stored in memory
# Data from grindavik stored in memory
# Call failed for wahran
# Data from bemidji stored in memory
# Data from bandarbeyla stored in memory
# Data from amazar stored in memory
# Data from valdivia stored in memory
# Data from karratha stored in memory
# Data from constitucion stored in memory
# Data from mampong stored in memory
# Data from half moon bay stored in memory
# Data from puerto escondido stored in memory
# Data from hasaki stored in memory
# Data from pochutla stored in memory
# Data from kovdor stored in memory
# Call failed for monte cristi
# Data from salalah stored in memory
# Data from natal stored in memory
# Data from klaksvik stored in memory
# Data from coihaique stored in memory
# Data from huarmey stored in memory
# Data from treznea stored in memory
# Data from yanam stored in memory
# Data from santa cruz de la palma stored in memory
# Data from nouadhibou stored in memory
# Data from longyearbyen stored in memory
# Data from los llanos de aridane stored in memory
# Data from geraldton stored in memory
# Data from nome stored in memory
# Data from beringovskiy stored in memory
# Data from belmonte stored in memory
# Data from parana stored in memory
# Call failed for karaul
# Data from quatre cocos stored in memory
# Data from casino stored in memory
# Data from pangkalanbuun stored in memory
# Data from tuktoyaktuk stored in memory
# Data from atuona stored in memory
# Data from belyy yar stored in memory
# Call failed for mrirt
# Data from adrar stored in memory
# Data from aklavik stored in memory
# Data from kushiro stored in memory
# Data from merauke stored in memory
# Data from bay city stored in memory
# Data from ormara stored in memory
# Call failed for samusu
# Data from jacqueville stored in memory
# Data from rimbey stored in memory
# Data from leningradskiy stored in memory
# Data from camacha stored in memory
# Data from kudahuvadhoo stored in memory
# Data from wewak stored in memory
# Data from khandbari stored in memory
# Data from dolores stored in memory
# Data from ampanihy stored in memory
# Data from alta floresta stored in memory
# Call failed for kamenskoye
# Data from nebolchi stored in memory
# Data from quelimane stored in memory
# Data from kaitangata stored in memory
# Data from quesnel stored in memory
# Data from severo-kurilsk stored in memory
# Data from yarmouth stored in memory
# Data from lazi stored in memory
# Data from lima stored in memory
# Data from hithadhoo stored in memory
# Data from muroto stored in memory
# Data from presidente olegario stored in memory
# Data from pangnirtung stored in memory
# Data from shimoda stored in memory
# Data from fernandina beach stored in memory
# Data from batemans bay stored in memory
# Data from sur stored in memory
# Data from hovd stored in memory
# Data from tambopata stored in memory
# Data from kavieng stored in memory
# Data from roquetas de mar stored in memory
# Data from tiksi stored in memory
# Data from beoumi stored in memory
# Data from belaya gora stored in memory
# Data from chake chake stored in memory
# Data from provideniya stored in memory
# Data from shingu stored in memory
# Data from bredasdorp stored in memory
# Call failed for galiwinku
# Data from tignere stored in memory
# Data from lagoa stored in memory
# Data from pakxe stored in memory
# Data from souillac stored in memory
# Data from jiangyou stored in memory
# Data from puerto leguizamo stored in memory
# Data from chumikan stored in memory
# Data from san vicente stored in memory
# Data from floro stored in memory
# Data from palmer stored in memory
# Data from tahe stored in memory
# Data from moose factory stored in memory
# Call failed for lolua
# Data from mahanoro stored in memory
# Data from babynino stored in memory
# Data from coquimbo stored in memory
# Data from vanimo stored in memory
# Data from nemuro stored in memory
# Data from grand gaube stored in memory
# Data from whitianga stored in memory
# Data from bismarck stored in memory
# Call failed for artyk
# Data from nizhniy mamon stored in memory
# Data from alveringem stored in memory
# Data from kuopio stored in memory
# Data from auki stored in memory
# Data from omsukchan stored in memory
# Data from acapulco stored in memory
# Data from verkhnevilyuysk stored in memory
# Data from chiang klang stored in memory
# Data from saint-pierre stored in memory
# Data from mount isa stored in memory
# Call failed for tabiauea
# Data from gamba stored in memory
# Data from zhigansk stored in memory
# Data from evensk stored in memory
# Data from nanortalik stored in memory
# Data from bela vista stored in memory
# Data from sumbe stored in memory
# Data from barao de melgaco stored in memory
# Data from port macquarie stored in memory
# Data from kruisfontein stored in memory
# Data from kimberley stored in memory
# Data from inhambane stored in memory
# Data from mezen stored in memory
# Data from slawno stored in memory
# Data from bayan stored in memory
# Data from arkhangelsk stored in memory
# Data from lompoc stored in memory
# Data from fare stored in memory
# Data from batagay stored in memory
# Data from vila franca do campo stored in memory
# Data from comodoro rivadavia stored in memory
# Data from kapit stored in memory
# Call failed for tabukiniberu
# Data from luderitz stored in memory
# Data from juneau stored in memory
# Data from dunedin stored in memory
# Data from sabang stored in memory
# Data from maumere stored in memory
# Data from vanavara stored in memory
# Data from viedma stored in memory
# Data from bundaberg stored in memory
# Data from napier stored in memory
# Data from piacabucu stored in memory
# Data from marystown stored in memory
# Data from port hardy stored in memory
# Call failed for umzimvubu
# Data from taltal stored in memory
# Data from portsmouth stored in memory
# Data from atar stored in memory
# Data from uetersen stored in memory
# Data from paita stored in memory
# Data from khatanga stored in memory
# Data from srednekolymsk stored in memory
# Data from pozo colorado stored in memory
# Data from sorland stored in memory
# Data from guerrero negro stored in memory
# Data from aasiaat stored in memory
# Data from hami stored in memory
# Data from hernani stored in memory
# Data from kirakira stored in memory
# Data from calabozo stored in memory
# Data from rio tercero stored in memory
# Data from ugoofaaru stored in memory
# Data from verkhnedneprovskiy stored in memory
# Data from jijiga stored in memory
# Data from safaga stored in memory
# Data from aquiraz stored in memory
# Data from nabire stored in memory
# Data from shubarkuduk stored in memory
# Data from westport stored in memory
# Data from basco stored in memory
# Data from karatuzskoye stored in memory
# Data from saint-joseph stored in memory
# Data from nara stored in memory
# Data from mareeba stored in memory
# Data from santa catarina de tepehuanes stored in memory
# Data from kavaratti stored in memory
# Data from mpigi stored in memory
# Data from maxixe stored in memory
# Data from kachug stored in memory
# Data from maningrida stored in memory
# Data from tooele stored in memory
# Data from la grande stored in memory
# Data from bertinoro stored in memory
# Data from ingham stored in memory
# Data from gejiu stored in memory
# Data from miles city stored in memory
# Data from gizo stored in memory
# Call failed for toftir
# Data from casablanca stored in memory
# Call failed for mendahara
# Data from tahta stored in memory
# Data from zhemtala stored in memory
# Data from touros stored in memory
# Data from great yarmouth stored in memory
# Data from meulaboh stored in memory
# Data from waipawa stored in memory
# Data from crepy-en-valois stored in memory
# Data from baturaja stored in memory
# Data from praia stored in memory
# Data from vila velha stored in memory
# Data from cartagena del chaira stored in memory
# Data from bugasong stored in memory
# Data from oktyabrskoye stored in memory
# Data from iringa stored in memory
# Data from honningsvag stored in memory
# Call failed for xiongshi
# Data from kahului stored in memory
# Data from lincoln stored in memory
# Data from kissidougou stored in memory
# Call failed for vaitupu
# Data from aksarka stored in memory
# Data from semey stored in memory
# Data from nogliki stored in memory
# Data from yar-sale stored in memory
# Data from charters towers stored in memory
# Data from cuiluan stored in memory
# Call failed for phnum penh
# Data from morant bay stored in memory
# Data from alice springs stored in memory
# Data from sabha stored in memory
# Data from puerto cabezas stored in memory
# Data from rawson stored in memory
# Data from mackenzie stored in memory
# Call failed for grand river south east
# Data from rey bouba stored in memory
# Data from mount gambier stored in memory
# Data from san quintin stored in memory
# Data from vestmannaeyjar stored in memory
# Data from mahibadhoo stored in memory
# Data from cockburn town stored in memory
# Data from abeche stored in memory
# Data from wanning stored in memory
# Data from katherine stored in memory
# Data from ushtobe stored in memory
# Data from lata stored in memory
# Data from alta gracia stored in memory
# Call failed for sentyabrskiy
# Data from kashi stored in memory
# Call failed for cheuskiny
# Data from krasnoye stored in memory
# Data from marienburg stored in memory
# Call failed for malwan
# Data from morros stored in memory
# Data from maine-soroa stored in memory
# Data from weihe stored in memory
# Data from chifeng stored in memory
# Data from ranong stored in memory
# Data from dezful stored in memory
# Data from birur stored in memory
# Data from cumbum stored in memory
# Data from oum hadjer stored in memory
# Data from bondo stored in memory
# Data from sao jose da coroa grande stored in memory
# Data from umm lajj stored in memory
# Data from ximei stored in memory
# Data from neiafu stored in memory
# Data from tete stored in memory
# Call failed for phan rang
# Data from saint anthony stored in memory
# Data from mountrath stored in memory
# Data from san martin stored in memory
# Data from kalmunai stored in memory
# Data from yairipok stored in memory
# Data from kangaba stored in memory
# Data from almeirim stored in memory
# Data from san luis stored in memory
# Data from tautira stored in memory
# Call failed for ngukurr
# Data from catamarca stored in memory
# Data from walvis bay stored in memory
# Data from rio gallegos stored in memory
# Data from putyatino stored in memory
# Data from luan stored in memory
# Data from yeppoon stored in memory
# Data from pergamino stored in memory
# Call failed for aflu
# Call failed for louisbourg
# Data from baglan stored in memory
# Data from ambilobe stored in memory
# Data from palana stored in memory
# Data from lerwick stored in memory
# Data from kloulklubed stored in memory
# Data from kampong cham stored in memory
# Data from pemangkat stored in memory
# Data from matara stored in memory
# Data from khani stored in memory
# Data from arlit stored in memory
# Data from ipira stored in memory
# Data from yenagoa stored in memory
# Data from san andres stored in memory
# Data from alyangula stored in memory
# Data from wiarton stored in memory
# Data from valparaiso stored in memory
# Data from garowe stored in memory
# Data from nouakchott stored in memory
# Data from marsh harbour stored in memory
# Data from san vicente de chucuri stored in memory
# Data from avanigadda stored in memory
# Call failed for urdzhar
# Data from danshui stored in memory
# Data from salinopolis stored in memory
# Data from sorong stored in memory
# Data from naron stored in memory
# Data from vakhrushevo stored in memory
# Data from malumfashi stored in memory
# Data from tallahassee stored in memory
# Data from pisco stored in memory
# Data from denpasar stored in memory
# Data from ust-kut stored in memory
# Data from pitimbu stored in memory
# Data from tokur stored in memory
# Data from maceio stored in memory
# Data from mnogovershinnyy stored in memory
# Data from kailua stored in memory
# Data from hurricane stored in memory
# Data from coahuayana stored in memory
# Data from ostrovnoy stored in memory
# Data from nowy dwor gdanski stored in memory
# Data from saposoa stored in memory
# Data from nenjiang stored in memory
# Data from cardston stored in memory
# Data from kenai stored in memory
# Data from kvam stored in memory
# Data from la cumbre stored in memory
# Data from porto santo stored in memory
# Data from bungu stored in memory
# Data from konstantinovka stored in memory
# Call failed for shkotovo-26
# Data from talnakh stored in memory
# Data from winchester stored in memory
# Data from santa cruz stored in memory
# Data from bayangol stored in memory
# Data from sandwick stored in memory
# Data from tiznit stored in memory
# Data from atasu stored in memory
# Data from uarini stored in memory
# Data from acarau stored in memory
# Data from kostino stored in memory
# Data from cidreira stored in memory
# Data from sechura stored in memory
# Data from uyemskiy stored in memory
# Call failed for yirol
# Data from union stored in memory
# Data from ambovombe stored in memory
# Data from sitka stored in memory
# Data from berlevag stored in memory
# Data from baruun-urt stored in memory
# Data from namikupa stored in memory
# Data from batticaloa stored in memory
# Data from zelenoborskiy stored in memory
# Data from buraydah stored in memory
# Data from ketchikan stored in memory
# Data from kawalu stored in memory
# Data from tecpan stored in memory
# Data from mayya stored in memory
# Data from bonthe stored in memory
# Data from kayerkan stored in memory
# Data from aranos stored in memory
# Data from timizart stored in memory
# Data from camocim stored in memory
# Data from zaraza stored in memory
# Data from wilmington stored in memory
# Call failed for nizhneyansk
# Data from salihorsk stored in memory
# Data from sergeyevka stored in memory
# Data from lorengau stored in memory
# Data from valle hermoso stored in memory
# Data from marang stored in memory
# Data from victor harbor stored in memory
# Data from buala stored in memory
# Data from godalming stored in memory
# Data from san patricio stored in memory
# Data from namtsy stored in memory
# Data from karlskrona stored in memory
# Data from san policarpo stored in memory
# Data from eydhafushi stored in memory
# Data from luau stored in memory
# Data from sarab stored in memory
# Data from manuk mangkaw stored in memory
# Data from bonavista stored in memory
# Data from sumy stored in memory
# Data from tocopilla stored in memory
# Data from karasburg stored in memory
# Data from bambanglipuro stored in memory
# Call failed for barawe
# Data from nago stored in memory
# Data from kabale stored in memory
# Data from plettenberg bay stored in memory
# Data from ocos stored in memory
# Data from yulara stored in memory
# Data from issoire stored in memory
# Data from dashitou stored in memory
# Data from whitecourt stored in memory
# Data from bratsk stored in memory
# Data from cajamarca stored in memory
# Data from tabas stored in memory
# Data from yokadouma stored in memory
# Data from ericeira stored in memory
# Data from pierre stored in memory
# Data from mwense stored in memory
# Data from ambunti stored in memory
# Data from olinda stored in memory
# Data from cordoba stored in memory
# Call failed for sofiysk
# Data from lircay stored in memory
# Data from hofn stored in memory
# Data from kushmurun stored in memory
# Data from quixeramobim stored in memory

# %%
#compose a dataframe from the lists accumulated

w_dict = {'city_name': c_names, 'country':c_codes, 'date': dates, 'lat':lats, 'lon':lons, 'max_temp_C': m_temp,
         'cloud_cover%': c_covs, 'humidity%': hums, 'wind_speed': wnd}

w_df = pd.DataFrame(w_dict)

w_df.head(15)
# Out:
#             city_name country        date      lat       lon  max_temp_C  \
# 0         George Town      MY  1609884235   5.4112  100.3354       25.00
# 1      Port Elizabeth      ZA  1609884235 -33.9180   25.5701       21.00
# 2         Port-Gentil      GA  1609884235  -0.7193    8.7815       28.00
# 3              Rabaul      PG  1609884235  -4.1967  152.1721       25.11
# 4              Dingle      PH  1609884236  10.9995  122.6711       23.56
# 5     Arraial do Cabo      BR  1609884236 -22.9661  -42.0278       28.00
# 6              Faanui      PF  1609884236 -16.4833 -151.7500       27.39
# 7              Lobito      AO  1609884236 -12.3481   13.5456       24.23
# 8              Albany      US  1609884133  42.6001  -73.9662        1.11
# 9            Hermanus      ZA  1609884237 -34.4187   19.2345       15.56
# 10          Busselton      AU  1609884061 -33.6500  115.3333       15.00
# 11  Zverinogolovskoye      RU  1609884238  54.4586   64.8542      -19.86
# 12            Samarai      PG  1609884238 -10.6167  150.6667       28.96
# 13            Rikitea      PF  1609884238 -23.1203 -134.9692       25.01
# 14            Ushuaia      AR  1609884239 -54.8000  -68.3000       14.00
#
#     cloud_cover%  humidity%  wind_speed
# 0           40.0       94.0        3.10
# 1           58.0       83.0        1.50
# 2           75.0       88.0        4.10
# 3          100.0       87.0        0.51
# 4           87.0       91.0        3.43
# 5           40.0       74.0        5.10
# 6           14.0       75.0        5.80
# 7            0.0       78.0        2.91
# 8           97.0       81.0        1.30
# 9            2.0       91.0        0.97
# 10          20.0       78.0        1.34
# 11         100.0       90.0        2.74
# 12          93.0       78.0        4.45
# 13           0.0       76.0        5.84
# 14          75.0       50.0        6.20

# %%
#write an output .csv for the data

w_df.to_csv('city_weather_1_5_21_try2.csv', index = False)
